# %%
print("Databricks Class - 1")

# %%
table_name = "samples.accuweather.forecast_daily_calendar_metric"
df = spark.table(table_name)
display(df)
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
df = spark.sql(f"select * from {table_name} where city_name='singapore'")
display(df)

# %%
players_df = spark.read.csv("/Volumes/pie-database/default/rawdata/players.csv", header=True)
display(players_df)

# %%
players_df = spark.read.csv("/Volumes/pie-database/default/rawdata/players.csv", header=True, inferSchema=True)
display(players_df)

# %%
players_df = (
    spark.read.format("csv")
    .option("header", True)
    .option("inferSchema", True)
    .load("/Volumes/pie-database/default/rawdata/players.csv")
)
display(players_df)
